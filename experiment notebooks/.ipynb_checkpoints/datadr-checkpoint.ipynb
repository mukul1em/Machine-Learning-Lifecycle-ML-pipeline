# %%
import pandas as pd

from datetime import datetime
from sklearn import datasets, ensemble, model_selection

from evidently.dashboard import Dashboard
from evidently.pipeline.column_mapping import ColumnMapping
from evidently.dashboard.tabs import ClassificationPerformanceTab

from evidently.model_profile import Profile
from evidently.model_profile.sections import ClassificationPerformanceProfileSection

# %%
df = pd.read_csv(r'D:\MUKUL ML\New folder (2)\Machine-Learning-Lifecycle-ML-pipeline\data versions\training_data.csv')
target = 'Class'
prediction = 'prediction'

numerical_features = df.columns
categorical_features = []

features = numerical_features.tolist() + categorical_features

# %%
import pandas as pd
from sklearn import datasets

from evidently.dashboard import Dashboard
from evidently.dashboard.tabs import DataDriftTab

iris = datasets.load_iris()
iris_frame = pd.DataFrame(iris.data, columns = iris.feature_names)

iris_data_drift_report = Dashboard(tabs=[DataDriftTab()])
iris_data_drift_report.calculate(iris_frame[:100], iris_frame[100:])

# %%
iris_data_drift_report.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
# </style>
# <script>
#     var evidently_dashboard_ea7ac56f97cd4fdf81294f228a98691d = {"name": "evidently_dashboard_ea7ac56f97cd4fdf81294f228a98691d", "widgets": [{"type": "big_table", "title": "Drift is detected for 75.00% of features (3 out of 4). Dataset Drift is detected.", "size": 2, "details": "", "alertsPosition": "row", "alertStats": {}, "params": {"rowsPerPage": 4, "columns": [{"title": "Feature", "field": "f1"}, {"title": "Type", "field": "f6"}, {"title": "Reference Distribution", "field": "f3", "type": "histogram", "options": {"xField": "x", "yField": "y"}}, {"title": "Current Distribution", "field": "f4", "type": "histogram", "options": {"xField": "x", "yField": "y"}}, {"title": "Data drift", "field": "f2"}, {"title": "P-Value for Similarity Test", "field": "f5", "sort": "asc"}], "data": [{"details": {"parts": [{"title": "Data drift", "id": "sepal length (cm)_drift", "type": "widget"}, {"title": "Data distribution", "id": "sepal length (cm)_distr"}], "insights": []}, "f1": "sepal length (cm)", "f6": "num", "f3": {"x": [4.3, 4.57, 4.84, 5.109999999999999, 5.38, 5.65, 5.92, 6.1899999999999995, 6.46, 6.73, 7.0], "y": [0.18518518518518487, 0.40740740740740805, 0.8888888888888903, 0.18518518518518487, 0.6666666666666656, 0.48148148148148223, 0.2962962962962968, 0.2592592592592588, 0.22222222222222185, 0.11111111111111129]}, "f4": {"x": [4.9, 5.2, 5.5, 5.800000000000001, 6.1000000000000005, 6.4, 6.7, 7.0, 7.300000000000001, 7.6, 7.9], "y": [0.06666666666666671, 0.0, 0.3333333333333326, 0.3333333333333335, 0.5333333333333337, 0.6000000000000003, 0.666666666666667, 0.3333333333333326, 0.0666666666666669, 0.3999999999999991]}, "f2": "Detected", "f5": 0.0}, {"details": {"parts": [{"title": "Data drift", "id": "sepal width (cm)_drift", "type": "widget"}, {"title": "Data distribution", "id": "sepal width (cm)_distr"}], "insights": []}, "f1": "sepal width (cm)", "f6": "num", "f3": {"x": [2.0, 2.24, 2.48, 2.72, 2.96, 3.2, 3.4400000000000004, 3.6800000000000006, 3.9200000000000004, 4.16, 4.4], "y": [0.12499999999999989, 0.29166666666666696, 0.49999999999999956, 0.5833333333333339, 0.8749999999999993, 0.8749999999999993, 0.37499999999999967, 0.37500000000000033, 0.08333333333333341, 0.08333333333333327]}, "f4": {"x": [2.2, 2.3600000000000003, 2.52, 2.68, 2.84, 3.0, 3.16, 3.3200000000000003, 3.48, 3.6399999999999997, 3.8], "y": [0.12499999999999989, 0.5000000000000009, 0.24999999999999978, 1.5000000000000029, 0.24999999999999978, 1.9999999999999982, 0.9999999999999991, 0.25000000000000044, 0.12500000000000022, 0.24999999999999978]}, "f2": "Not Detected", "f5": 0.075329}, {"details": {"parts": [{"title": "Data drift", "id": "petal length (cm)_drift", "type": "widget"}, {"title": "Data distribution", "id": "petal length (cm)_distr"}], "insights": []}, "f1": "petal length (cm)", "f6": "num", "f3": {"x": [1.0, 1.41, 1.8199999999999998, 2.23, 2.6399999999999997, 3.05, 3.46, 3.8699999999999997, 4.279999999999999, 4.6899999999999995, 5.1], "y": [0.5853658536585367, 0.5853658536585367, 0.04878048780487803, 0.0, 0.024390243902439015, 0.04878048780487803, 0.12195121951219522, 0.36585365853658564, 0.39024390243902424, 0.2682926829268292]}, "f4": {"x": [4.5, 4.74, 4.98, 5.220000000000001, 5.46, 5.7, 5.94, 6.180000000000001, 6.42, 6.66, 6.9], "y": [0.08333333333333327, 0.4166666666666663, 0.9999999999999991, 0.33333333333333426, 0.7499999999999993, 0.6666666666666662, 0.4166666666666663, 0.16666666666666713, 0.08333333333333327, 0.24999999999999978]}, "f2": "Detected", "f5": 0.0}, {"details": {"parts": [{"title": "Data drift", "id": "petal width (cm)_drift", "type": "widget"}, {"title": "Data distribution", "id": "petal width (cm)_distr"}], "insights": []}, "f1": "petal width (cm)", "f6": "num", "f3": {"x": [0.1, 0.27, 0.43999999999999995, 0.61, 0.7799999999999999, 0.9499999999999998, 1.12, 1.29, 1.46, 1.63, 1.8], "y": [1.9999999999999998, 0.8235294117647062, 0.11764705882352938, 0.0, 0.0, 0.5882352941176462, 0.29411764705882365, 1.1764705882352946, 0.764705882352941 ...
